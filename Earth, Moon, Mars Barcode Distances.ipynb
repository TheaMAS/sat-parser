# %% [markdown]
# # Earth / Moon vs. Earth / Mars Barcodes

# %% [markdown]
# ### Setup Base

# %%
from os_utilities import *
from orb_builder import *

orb_filenames = [] # used to keep track of what files to feed into soap

folder_name = "sim-2023-01-26"
prefix = "starlink" # earth / moon / mars
n = 50 # number of simulations to generate
k = 50 # number of satellites to sample from starlink

folder = "./outputs/" + folder_name
make_folder(folder)

starlink = build_satellites_csv("starlink")
moon_sats = get_moon_platforms()
mars_sats = get_mars_platforms()
ground = [
    create_ground_object_dictionary("Ground-Albany", 42.685012663456163, -73.82479012295363, 0),
    create_ground_object_dictionary("Ground-Sydney", -33.868888888888889, 151.20939697339508, 0)
]
norad = build_satellites_from_tle("./sources/tdrss.tle")

# %%
for i in range(n):
    name = prefix + "_" + str(k) + "_sats_" + str(i)

    subset = sample_sats(starlink, k)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset # + ground

    orb_filenames.append(name + ".orb")

    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Earth / Moon System

# %%
for i in range(n):
    name = prefix + "_moon_" + str(i)

    subset = sample_sats(starlink, k)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset + moon_sats # + ground

    orb_filenames.append(name + ".orb")

    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Earth / Mars System

# %%
for i in range(n):
    
    name = prefix + "_mars_" + str(i)

    subset = sample_sats(starlink, k + 1)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset + mars_sats # + ground

    orb_filenames.append(name + ".orb")

    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Run Soap

# %%
# folder = "outputs/starlink-6"
# orb_files = get_ext_files(folder, "orb")
# orb_filenames = []
# for orb_file in orb_files:
#     orb_filenames.append(orb_file.split("/")[-1])
# print(orb_filenames)

# %%
import subprocess

command = "wine"
soap_path = "/home/zeno/.wine/drive_c/SOAP/bin64/soap.exe"

for filename in orb_filenames:
#     print(filename)

    orb_path = "" + folder + "/" + filename + ""
    process = subprocess.Popen([command, soap_path, orb_path])
    # process = subprocess.Popen([command, soap_path, orb_path], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    process.wait()
# Out:
# 0084:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0084:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0084:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0084:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0114:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 00d0:fixme:wintab32:x11drv_tablet_info Return proper size
# 00d0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 006c:fixme:imm:ImeSetActiveContext (0000000000010026, 0): stub
# 006c:fixme:imm:ImmReleaseContext (0000000000010020, 0000000000010026): stub
# 00d0:fixme:imm:ImeSetActiveContext (000000000002004A, 1): stub
# 00d0:fixme:imm:ImmReleaseContext (000000000001006E, 000000000002004A): stub
# 00d0:fixme:win:RegisterTouchWindow hwnd 000000000001006E, flags 0 stub!
# 00d0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 00d0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 00d0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 00d0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 00d0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 00d0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 00d0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 00d0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 013c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 012c:fixme:wintab32:x11drv_tablet_info Return proper size
# 012c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 012c:fixme:imm:ImeSetActiveContext (0000000000180074, 1): stub
# 012c:fixme:imm:ImmReleaseContext (0000000000020062, 0000000000180074): stub
# 012c:fixme:win:RegisterTouchWindow hwnd 0000000000020062, flags 0 stub!
# 012c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 012c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 012c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 012c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 012c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 012c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 012c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 012c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0164:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0154:fixme:wintab32:x11drv_tablet_info Return proper size
# 0154:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0154:fixme:imm:ImeSetActiveContext (0000000000030080, 1): stub
# 0154:fixme:imm:ImmReleaseContext (0000000000030046, 0000000000030080): stub
# 0154:fixme:win:RegisterTouchWindow hwnd 0000000000030046, flags 0 stub!
# 0154:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0154:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0154:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0154:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0154:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0154:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0154:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0154:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 018c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 017c:fixme:wintab32:x11drv_tablet_info Return proper size
# 017c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 017c:fixme:imm:ImeSetActiveContext (0000000000040080, 1): stub
# 017c:fixme:imm:ImmReleaseContext (0000000000040060, 0000000000040080): stub
# 017c:fixme:win:RegisterTouchWindow hwnd 0000000000040060, flags 0 stub!
# 017c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 017c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 017c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 017c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 017c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 017c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 017c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 017c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 01b4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01a4:fixme:wintab32:x11drv_tablet_info Return proper size
# 01a4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01a4:fixme:imm:ImeSetActiveContext (000000000007007A, 1): stub
# 01a4:fixme:imm:ImmReleaseContext (00000000001B0074, 000000000007007A): stub
# 01a4:fixme:win:RegisterTouchWindow hwnd 00000000001B0074, flags 0 stub!
# 01a4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 01a4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01a4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01a4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01a4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01a4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01a4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01a4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 01dc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01cc:fixme:wintab32:x11drv_tablet_info Return proper size
# 01cc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01cc:fixme:imm:ImeSetActiveContext (00000000003F0076, 1): stub
# 01cc:fixme:imm:ImmReleaseContext (000000000029006C, 00000000003F0076): stub
# 01cc:fixme:win:RegisterTouchWindow hwnd 000000000029006C, flags 0 stub!
# 01cc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 01cc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01cc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01cc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01cc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01cc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01cc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01cc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0204:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01f4:fixme:wintab32:x11drv_tablet_info Return proper size
# 01f4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01f4:fixme:imm:ImeSetActiveContext (0000000000420074, 1): stub
# 01f4:fixme:imm:ImmReleaseContext (0000000000080064, 0000000000420074): stub
# 01f4:fixme:win:RegisterTouchWindow hwnd 0000000000080064, flags 0 stub!
# 01f4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 01f4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01f4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01f4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01f4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01f4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01f4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01f4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 022c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 021c:fixme:wintab32:x11drv_tablet_info Return proper size
# 021c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 021c:fixme:imm:ImeSetActiveContext (000000000009007C, 1): stub
# 021c:fixme:imm:ImmReleaseContext (000000000008005E, 000000000009007C): stub
# 021c:fixme:win:RegisterTouchWindow hwnd 000000000008005E, flags 0 stub!
# 021c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 021c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 021c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 021c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 021c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 021c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 021c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 021c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0254:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0244:fixme:wintab32:x11drv_tablet_info Return proper size
# 0244:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0244:fixme:imm:ImeSetActiveContext (00000000000A007C, 1): stub
# 0244:fixme:imm:ImmReleaseContext (00000000000A005A, 00000000000A007C): stub
# 0244:fixme:win:RegisterTouchWindow hwnd 00000000000A005A, flags 0 stub!
# 0244:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0244:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0244:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0244:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0244:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0244:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0244:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0244:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 027c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 026c:fixme:wintab32:x11drv_tablet_info Return proper size
# 026c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 026c:fixme:imm:ImeSetActiveContext (00000000000B007C, 1): stub
# 026c:fixme:imm:ImmReleaseContext (00000000002C006A, 00000000000B007C): stub
# 026c:fixme:win:RegisterTouchWindow hwnd 00000000002C006A, flags 0 stub!
# 026c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 026c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 026c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 026c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 026c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 026c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 026c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 026c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02a4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0294:fixme:wintab32:x11drv_tablet_info Return proper size
# 0294:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0294:fixme:imm:ImeSetActiveContext (00000000000E007A, 1): stub
# 0294:fixme:imm:ImmReleaseContext (00000000002F0064, 00000000000E007A): stub
# 0294:fixme:win:RegisterTouchWindow hwnd 00000000002F0064, flags 0 stub!
# 0294:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0294:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0294:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0294:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0294:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0294:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0294:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0294:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02cc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 02bc:fixme:wintab32:x11drv_tablet_info Return proper size
# 02bc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 02bc:fixme:imm:ImeSetActiveContext (0000000000460076, 1): stub
# 02bc:fixme:imm:ImmReleaseContext (00000000002D005E, 0000000000460076): stub
# 02bc:fixme:win:RegisterTouchWindow hwnd 00000000002D005E, flags 0 stub!
# 02bc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 02bc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02bc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02bc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 02bc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 02bc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 02bc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 02bc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02f4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 02e4:fixme:wintab32:x11drv_tablet_info Return proper size
# 02e4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 02e4:fixme:imm:ImeSetActiveContext (0000000000470076, 1): stub
# 02e4:fixme:imm:ImmReleaseContext (00000000002B005A, 0000000000470076): stub
# 02e4:fixme:win:RegisterTouchWindow hwnd 00000000002B005A, flags 0 stub!
# 02e4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 02e4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02e4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02e4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 02e4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 02e4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 02e4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 02e4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 031c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 030c:fixme:wintab32:x11drv_tablet_info Return proper size
# 030c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 030c:fixme:imm:ImeSetActiveContext (0000000000480076, 1): stub
# 030c:fixme:imm:ImmReleaseContext (0000000000100068, 0000000000480076): stub
# 030c:fixme:win:RegisterTouchWindow hwnd 0000000000100068, flags 0 stub!
# 030c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 030c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 030c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 030c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 030c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 030c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 030c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 030c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0344:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0334:fixme:wintab32:x11drv_tablet_info Return proper size
# 0334:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0334:fixme:imm:ImeSetActiveContext (0000000000490076, 1): stub
# 0334:fixme:imm:ImmReleaseContext (0000000000520064, 0000000000490076): stub
# 0334:fixme:win:RegisterTouchWindow hwnd 0000000000520064, flags 0 stub!
# 0334:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0334:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0334:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0334:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0334:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0334:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0334:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0334:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 036c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 035c:fixme:wintab32:x11drv_tablet_info Return proper size
# 035c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 035c:fixme:imm:ImeSetActiveContext (00000000004A0076, 1): stub
# 035c:fixme:imm:ImmReleaseContext (00000000004E005E, 00000000004A0076): stub
# 035c:fixme:win:RegisterTouchWindow hwnd 00000000004E005E, flags 0 stub!
# 035c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 035c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 035c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 035c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 035c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 035c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 035c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 035c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0394:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0384:fixme:wintab32:x11drv_tablet_info Return proper size
# 0384:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0384:fixme:imm:ImeSetActiveContext (00000000004B0076, 1): stub
# 0384:fixme:imm:ImmReleaseContext (00000000004B005A, 00000000004B0076): stub
# 0384:fixme:win:RegisterTouchWindow hwnd 00000000004B005A, flags 0 stub!
# 0384:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0384:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0384:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0384:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0384:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0384:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0384:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0384:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 03bc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03ac:fixme:wintab32:x11drv_tablet_info Return proper size
# 03ac:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03ac:fixme:imm:ImeSetActiveContext (00000000004C0076, 1): stub
# 03ac:fixme:imm:ImmReleaseContext (0000000000330068, 00000000004C0076): stub
# 03ac:fixme:win:RegisterTouchWindow hwnd 0000000000330068, flags 0 stub!
# 03ac:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 03ac:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03ac:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03ac:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03ac:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03ac:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03ac:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03ac:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 03e4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03d4:fixme:wintab32:x11drv_tablet_info Return proper size
# 03d4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03d4:fixme:imm:ImeSetActiveContext (00000000004D0076, 1): stub
# 03d4:fixme:imm:ImmReleaseContext (0000000000740064, 00000000004D0076): stub
# 03d4:fixme:win:RegisterTouchWindow hwnd 0000000000740064, flags 0 stub!
# 03d4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 03d4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03d4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03d4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03d4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03d4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03d4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03d4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 040c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03fc:fixme:wintab32:x11drv_tablet_info Return proper size
# 03fc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03fc:fixme:imm:ImeSetActiveContext (00000000004E0076, 1): stub
# 03fc:fixme:imm:ImmReleaseContext (000000000072004A, 00000000004E0076): stub
# 03fc:fixme:win:RegisterTouchWindow hwnd 000000000072004A, flags 0 stub!
# 03fc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 03fc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03fc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03fc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03fc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03fc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03fc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03fc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0434:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0424:fixme:wintab32:x11drv_tablet_info Return proper size
# 0424:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0424:fixme:imm:ImeSetActiveContext (00000000004F0076, 1): stub
# 0424:fixme:imm:ImmReleaseContext (0000000000190072, 00000000004F0076): stub
# 0424:fixme:win:RegisterTouchWindow hwnd 0000000000190072, flags 0 stub!
# 0424:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0424:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0424:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0424:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0424:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0424:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0424:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0424:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 045c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 044c:fixme:wintab32:x11drv_tablet_info Return proper size
# 044c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 044c:fixme:imm:ImeSetActiveContext (0000000000500076, 1): stub
# 044c:fixme:imm:ImmReleaseContext (0000000000570068, 0000000000500076): stub
# 044c:fixme:win:RegisterTouchWindow hwnd 0000000000570068, flags 0 stub!
# 044c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 044c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 044c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 044c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 044c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 044c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 044c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 044c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0484:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0474:fixme:wintab32:x11drv_tablet_info Return proper size
# 0474:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0474:fixme:imm:ImeSetActiveContext (0000000000510076, 1): stub
# 0474:fixme:imm:ImmReleaseContext (0000000000780064, 0000000000510076): stub
# 0474:fixme:win:RegisterTouchWindow hwnd 0000000000780064, flags 0 stub!
# 0474:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0474:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0474:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0474:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0474:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0474:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0474:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0474:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04ac:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 049c:fixme:wintab32:x11drv_tablet_info Return proper size
# 049c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 049c:fixme:imm:ImeSetActiveContext (00000000005A006A, 1): stub
# 049c:fixme:imm:ImmReleaseContext (0000000000180066, 00000000005A006A): stub
# 049c:fixme:win:RegisterTouchWindow hwnd 0000000000180066, flags 0 stub!
# 049c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 049c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 049c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 049c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 049c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 049c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 049c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 049c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04d4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 04c4:fixme:wintab32:x11drv_tablet_info Return proper size
# 04c4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 04c4:fixme:imm:ImeSetActiveContext (00000000001C006E, 1): stub
# 04c4:fixme:imm:ImmReleaseContext (000000000076005E, 00000000001C006E): stub
# 04c4:fixme:win:RegisterTouchWindow hwnd 000000000076005E, flags 0 stub!
# 04c4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 04c4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04c4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04c4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 04c4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 04c4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 04c4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 04c4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04fc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 04ec:fixme:wintab32:x11drv_tablet_info Return proper size
# 04ec:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 04ec:fixme:imm:ImeSetActiveContext (00000000001D0070, 1): stub
# 04ec:fixme:imm:ImmReleaseContext (00000000001C0058, 00000000001D0070): stub
# 04ec:fixme:win:RegisterTouchWindow hwnd 00000000001C0058, flags 0 stub!
# 04ec:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 04ec:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04ec:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04ec:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 04ec:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 04ec:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 04ec:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 04ec:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0524:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0514:fixme:wintab32:x11drv_tablet_info Return proper size
# 0514:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0514:fixme:imm:ImeSetActiveContext (0000000000590074, 1): stub
# 0514:fixme:imm:ImmReleaseContext (0000000000980064, 0000000000590074): stub
# 0514:fixme:win:RegisterTouchWindow hwnd 0000000000980064, flags 0 stub!
# 0514:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0514:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0514:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0514:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0514:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0514:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0514:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0514:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 054c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 053c:fixme:wintab32:x11drv_tablet_info Return proper size
# 053c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 053c:fixme:imm:ImeSetActiveContext (00000000005A0074, 1): stub
# 053c:fixme:imm:ImmReleaseContext (00000000003E0060, 00000000005A0074): stub
# 053c:fixme:win:RegisterTouchWindow hwnd 00000000003E0060, flags 0 stub!
# 053c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 053c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 053c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 053c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 053c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 053c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 053c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 053c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0574:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0564:fixme:wintab32:x11drv_tablet_info Return proper size
# 0564:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0564:fixme:imm:ImeSetActiveContext (00000000005B0074, 1): stub
# 0564:fixme:imm:ImmReleaseContext (000000000099005E, 00000000005B0074): stub
# 0564:fixme:win:RegisterTouchWindow hwnd 000000000099005E, flags 0 stub!
# 0564:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0564:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0564:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0564:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0564:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0564:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0564:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0564:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 059c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 058c:fixme:wintab32:x11drv_tablet_info Return proper size
# 058c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 058c:fixme:imm:ImeSetActiveContext (00000000005C0074, 1): stub
# 058c:fixme:imm:ImmReleaseContext (0000000000410058, 00000000005C0074): stub
# 058c:fixme:win:RegisterTouchWindow hwnd 0000000000410058, flags 0 stub!
# 058c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 058c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 058c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 058c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 058c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 058c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 058c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 058c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 05c4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 05b4:fixme:wintab32:x11drv_tablet_info Return proper size
# 05b4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 05b4:fixme:imm:ImeSetActiveContext (00000000005D0074, 1): stub
# 05b4:fixme:imm:ImmReleaseContext (0000000000BA0064, 00000000005D0074): stub
# 05b4:fixme:win:RegisterTouchWindow hwnd 0000000000BA0064, flags 0 stub!
# 05b4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 05b4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05b4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05b4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 05b4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 05b4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 05b4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 05b4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 05ec:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 05dc:fixme:wintab32:x11drv_tablet_info Return proper size
# 05dc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 05dc:fixme:imm:ImeSetActiveContext (00000000005E0074, 1): stub
# 05dc:fixme:imm:ImmReleaseContext (0000000000620060, 00000000005E0074): stub
# 05dc:fixme:win:RegisterTouchWindow hwnd 0000000000620060, flags 0 stub!
# 05dc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 05dc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05dc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05dc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 05dc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 05dc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 05dc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 05dc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0614:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0604:fixme:wintab32:x11drv_tablet_info Return proper size
# 0604:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0604:fixme:imm:ImeSetActiveContext (00000000005F0074, 1): stub
# 0604:fixme:imm:ImmReleaseContext (0000000000BC005E, 00000000005F0074): stub
# 0604:fixme:win:RegisterTouchWindow hwnd 0000000000BC005E, flags 0 stub!
# 0604:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0604:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0604:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0604:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0604:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0604:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0604:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0604:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 063c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 062c:fixme:wintab32:x11drv_tablet_info Return proper size
# 062c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 062c:fixme:imm:ImeSetActiveContext (0000000000600074, 1): stub
# 062c:fixme:imm:ImmReleaseContext (0000000000660058, 0000000000600074): stub
# 062c:fixme:win:RegisterTouchWindow hwnd 0000000000660058, flags 0 stub!
# 062c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 062c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 062c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 062c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 062c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 062c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 062c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 062c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0664:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0654:fixme:wintab32:x11drv_tablet_info Return proper size
# 0654:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0654:fixme:imm:ImeSetActiveContext (0000000000180082, 1): stub
# 0654:fixme:imm:ImmReleaseContext (00000000005F0076, 0000000000180082): stub
# 0654:fixme:win:RegisterTouchWindow hwnd 00000000005F0076, flags 0 stub!
# 0654:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0654:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0654:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0654:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0654:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0654:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0654:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0654:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 068c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 067c:fixme:wintab32:x11drv_tablet_info Return proper size
# 067c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 067c:fixme:imm:ImeSetActiveContext (0000000000190082, 1): stub
# 067c:fixme:imm:ImmReleaseContext (0000000000FB0046, 0000000000190082): stub
# 067c:fixme:win:RegisterTouchWindow hwnd 0000000000FB0046, flags 0 stub!
# 067c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 067c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 067c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 067c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 06b4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06a4:fixme:wintab32:x11drv_tablet_info Return proper size
# 06a4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06a4:fixme:imm:ImeSetActiveContext (0000000000750076, 1): stub
# 06a4:fixme:imm:ImmReleaseContext (000000000074006C, 0000000000750076): stub
# 06a4:fixme:win:RegisterTouchWindow hwnd 000000000074006C, flags 0 stub!
# 06a4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 06a4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06a4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06a4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06a4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06a4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06a4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06a4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 06dc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06cc:fixme:wintab32:x11drv_tablet_info Return proper size
# 06cc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06cc:fixme:imm:ImeSetActiveContext (0000000000760076, 1): stub
# 06cc:fixme:imm:ImmReleaseContext (00000000005F0072, 0000000000760076): stub
# 06cc:fixme:win:RegisterTouchWindow hwnd 00000000005F0072, flags 0 stub!
# 06cc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 06cc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06cc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06cc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06cc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06cc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06cc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06cc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0704:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06f4:fixme:wintab32:x11drv_tablet_info Return proper size
# 06f4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06f4:fixme:imm:ImeSetActiveContext (00000000002C006E, 1): stub
# 06f4:fixme:imm:ImmReleaseContext (00000000005A0066, 00000000002C006E): stub
# 06f4:fixme:win:RegisterTouchWindow hwnd 00000000005A0066, flags 0 stub!
# 06f4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 06f4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06f4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06f4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06f4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06f4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06f4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06f4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 072c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 071c:fixme:wintab32:x11drv_tablet_info Return proper size
# 071c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 071c:fixme:imm:ImeSetActiveContext (00000000002F0080, 1): stub
# 071c:fixme:imm:ImmReleaseContext (000000000062005C, 00000000002F0080): stub
# 071c:fixme:win:RegisterTouchWindow hwnd 000000000062005C, flags 0 stub!
# 071c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 071c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 071c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 071c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 071c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 071c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 071c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 071c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0754:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0744:fixme:wintab32:x11drv_tablet_info Return proper size
# 0744:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0744:fixme:imm:ImeSetActiveContext (0000000000300080, 1): stub
# 0744:fixme:imm:ImmReleaseContext (0000000000850060, 0000000000300080): stub
# 0744:fixme:win:RegisterTouchWindow hwnd 0000000000850060, flags 0 stub!
# 0744:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0744:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0744:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0744:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0744:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0744:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0744:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0744:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 077c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 076c:fixme:wintab32:x11drv_tablet_info Return proper size
# 076c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 076c:fixme:imm:ImeSetActiveContext (0000000000310080, 1): stub
# 076c:fixme:imm:ImmReleaseContext (00000000002A0062, 0000000000310080): stub
# 076c:fixme:win:RegisterTouchWindow hwnd 00000000002A0062, flags 0 stub!
# 076c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 076c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 076c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 076c:fixme:win:NtUserFlashWindowEx 0x11b990 - semi-stub
# 076c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 076c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 076c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 076c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 076c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07a4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0794:fixme:wintab32:x11drv_tablet_info Return proper size
# 0794:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0794:fixme:imm:ImeSetActiveContext (00000000004F007A, 1): stub
# 0794:fixme:imm:ImmReleaseContext (0000000001320046, 00000000004F007A): stub
# 0794:fixme:win:RegisterTouchWindow hwnd 0000000001320046, flags 0 stub!
# 0794:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0794:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0794:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0794:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0794:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0794:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0794:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0794:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07cc:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 07bc:fixme:wintab32:x11drv_tablet_info Return proper size
# 07bc:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 07bc:fixme:imm:ImeSetActiveContext (00000000002C0086, 1): stub
# 07bc:fixme:imm:ImmReleaseContext (00000000006B0074, 00000000002C0086): stub
# 07bc:fixme:win:RegisterTouchWindow hwnd 00000000006B0074, flags 0 stub!
# 07bc:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 07bc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07bc:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07bc:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 07bc:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 07bc:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 07bc:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 07bc:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07f4:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 07e4:fixme:wintab32:x11drv_tablet_info Return proper size
# 07e4:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 07e4:fixme:imm:ImeSetActiveContext (00000000004B007C, 1): stub
# 07e4:fixme:imm:ImmReleaseContext (0000000000A30060, 00000000004B007C): stub
# 07e4:fixme:win:RegisterTouchWindow hwnd 0000000000A30060, flags 0 stub!
# 07e4:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 07e4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07e4:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07e4:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 07e4:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 07e4:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 07e4:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 07e4:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 081c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 080c:fixme:wintab32:x11drv_tablet_info Return proper size
# 080c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 080c:fixme:imm:ImeSetActiveContext (00000000004C007C, 1): stub
# 080c:fixme:imm:ImmReleaseContext (000000000091006C, 00000000004C007C): stub
# 080c:fixme:win:RegisterTouchWindow hwnd 000000000091006C, flags 0 stub!
# 080c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 080c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 080c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 080c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 080c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 080c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 080c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 080c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0050:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0114:fixme:wintab32:x11drv_tablet_info Return proper size
# 0114:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0114:fixme:imm:ImeSetActiveContext (000000000034006E, 1): stub
# 0114:fixme:imm:ImmReleaseContext (00000000008B0068, 000000000034006E): stub
# 0114:fixme:win:RegisterTouchWindow hwnd 00000000008B0068, flags 0 stub!
# 0114:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0114:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0114:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0114:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0114:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0114:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0114:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0114:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0134:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0024:fixme:wintab32:x11drv_tablet_info Return proper size
# 0024:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0024:fixme:imm:ImeSetActiveContext (00000000007D0072, 1): stub
# 0024:fixme:imm:ImmReleaseContext (00000000007E0066, 00000000007D0072): stub
# 0024:fixme:win:RegisterTouchWindow hwnd 00000000007E0066, flags 0 stub!
# 0024:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0024:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0024:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0024:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0024:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0024:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0024:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0024:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 015c:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0124:fixme:wintab32:x11drv_tablet_info Return proper size
# 0124:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0124:fixme:imm:ImeSetActiveContext (000000000056007A, 1): stub
# 0124:fixme:imm:ImmReleaseContext (0000000000760058, 000000000056007A): stub
# 0124:fixme:win:RegisterTouchWindow hwnd 0000000000760058, flags 0 stub!
# 0124:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 0124:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0124:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0124:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0124:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0124:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0124:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0124:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0184:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 014c:fixme:wintab32:x11drv_tablet_info Return proper size
# 014c:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 014c:fixme:imm:ImeSetActiveContext (000000000057007A, 1): stub
# 014c:fixme:imm:ImmReleaseContext (000000000077006A, 000000000057007A): stub
# 014c:fixme:win:RegisterTouchWindow hwnd 000000000077006A, flags 0 stub!
# 014c:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# Mesa: User error: GL_OUT_OF_MEMORY in glNewList -> glBitmap
# 014c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 014c:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 014c:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 014c:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 014c:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 014c:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 014c:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image

# %% [markdown]
# ## Generate Barcodes

# %%
from zz_persistence import *

diagrams = {}
diagrams_clique = {}

filepaths = get_csv_files(folder)
for filepath in filepaths:
    if not filepath.endswith("Contact Analysis.csv"):
        continue
    contact_plan = ca.contact_analysis_parser(filepath)
    graph = ca.construct_graph(contact_plan)
    
    weighted_simplex = ca.construct_weighted_simplex(graph)
    clique_complex = ca.construct_clique_complex(graph)
    
    zz, dgms, cells = calculate_zz_persistence(weighted_simplex)
    zz_clique, dgms_clique, cells_clique = calculate_zz_persistence(clique_complex)
    
    diagrams[filepath.split("/")[-1]] = dgms
    diagrams_clique[filepath.split("/")[-1]] = dgms_clique
    
# print(diagrams)
# print(diagrams_clique)

# %%
dim = 1

# %% [markdown]
# ## Compare Earth / Moon Simulations

# %%
# Compare Earth / Moon
for i in range(n):
    for j in range(i + 1, n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_moon_" + str(j) + " Contact Analysis.csv"]
        
        diagram_a_clique = diagrams_clique["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_moon_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))

# %% [markdown]
# ## Compare Earth / Mars Simulations

# %%
# Compare Earth / Mars
for i in range(n):
    for j in range(i + 1, n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_mars_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_mars_" + str(j) + " Contact Analysis.csv"]

        diagram_a_clique = diagrams_clique["emm_mars_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_mars_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))

# %% [markdown]
# ## Cross Compare Moon / Mars

# %%
# Cross Compare Moon / Mars
for i in range(n):
    for j in range(n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_mars_" + str(j) + " Contact Analysis.csv"]
        
        diagram_a_clique = diagrams_clique["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_mars_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))
