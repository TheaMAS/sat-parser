# %% [markdown]
# # Earth / Moon vs. Earth / Mars Barcodes

# %% [markdown]
# ### Setup Base

# %%
from os_utilities import *
from orb_builder import *
import time_utilities as tu

orb_filenames = [] # used to keep track of what files to feed into soap

folder_name = "starlink-35-sat-single"
# folder_name = "starlink-100-sat-multiple"
prefix = "starlink" # earth / moon / mars
n = 50 # number of simulations to generate
k = 35 # number of satellites to sample from starlink

folder = "./outputs/" + folder_name
make_folder(folder)

starlink = build_satellites_csv("starlink")
moon_sats = get_moon_platforms()
mars_sats = get_mars_platforms()
ground = [
    create_ground_object_dictionary("Ground-Albany", 42.685012663456163, -73.82479012295363, 0),
    create_ground_object_dictionary("Ground-Sydney", -33.868888888888889, 151.20939697339508, 0)
]
norad = build_satellites_from_tle("./sources/tdrss.tle")

# %%
for i in range(n):
    name = prefix + "_" + str(k) + "_sats_" + str(i)

    subset = sample_sats(starlink, k)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset # + ground

    orb_filenames.append(name + ".orb")

    d = tu.get_random_date()
    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Earth / Moon System

# %%
for i in range(n):
    name = prefix + "_moon_" + str(i)

    subset = sample_sats(starlink, k)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset + moon_sats # + ground

    orb_filenames.append(name + ".orb")

    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Earth / Mars System

# %%
for i in range(n):
    
    name = prefix + "_mars_" + str(i)

    subset = sample_sats(starlink, k + 1)

    # track which satellites were chosen for subsequent simulations
    subset_names = []
    for satellite in subset:
        subset_names.append(satellite["object_name"])

    satellites = subset + mars_sats # + ground

    orb_filenames.append(name + ".orb")

    save_to_outputs_file(
        generate_orb(satellites, name),
        folder_name + "/" + name, "orb")

# %% [markdown]
# ## Run Soap

# %%
# folder = "outputs/starlink-6"
# orb_files = get_ext_files(folder, "orb")
# orb_filenames = []
# for orb_file in orb_files:
#     orb_filenames.append(orb_file.split("/")[-1])
# print(orb_filenames)

# %%
import subprocess

command = "wine"
soap_path = "/home/zeno/.wine/drive_c/SOAP/bin64/soap.exe"

for filename in orb_filenames:
#     print(filename)

    orb_path = "" + folder + "/" + filename + ""
    process = subprocess.Popen([command, soap_path, orb_path])
    # process = subprocess.Popen([command, soap_path, orb_path], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
    process.wait()
# Out:
# 007c:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 007c:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 007c:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 007c:fixme:hid:handle_IRP_MN_QUERY_ID Unhandled type 00000005
# 0110:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0100:fixme:wintab32:x11drv_tablet_info Return proper size
# 0100:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0100:fixme:imm:ImeSetActiveContext (0000000000010050, 1): stub
# 0100:fixme:imm:ImmReleaseContext (000000000001006E, 0000000000010050): stub
# 008c:fixme:imm:ImeSetActiveContext (0000000000010026, 0): stub
# 008c:fixme:imm:ImmReleaseContext (0000000000010020, 0000000000010026): stub
# 0100:fixme:win:RegisterTouchWindow hwnd 000000000001006E, flags 0 stub!
# 0100:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0100:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0100:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0138:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0128:fixme:wintab32:x11drv_tablet_info Return proper size
# 0128:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0128:fixme:imm:ImeSetActiveContext (0000000000020060, 1): stub
# 0128:fixme:imm:ImmReleaseContext (0000000000020066, 0000000000020060): stub
# 0128:fixme:win:RegisterTouchWindow hwnd 0000000000020066, flags 0 stub!
# 0128:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0128:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0128:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0160:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0150:fixme:wintab32:x11drv_tablet_info Return proper size
# 0150:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0150:fixme:imm:ImeSetActiveContext (000000000004007A, 1): stub
# 0150:fixme:imm:ImmReleaseContext (0000000000030056, 000000000004007A): stub
# 0150:fixme:win:RegisterTouchWindow hwnd 0000000000030056, flags 0 stub!
# 0150:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0150:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0150:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0188:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0178:fixme:wintab32:x11drv_tablet_info Return proper size
# 0178:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0178:fixme:imm:ImeSetActiveContext (000000000005007A, 1): stub
# 0178:fixme:imm:ImmReleaseContext (000000000004005A, 000000000005007A): stub
# 0178:fixme:win:RegisterTouchWindow hwnd 000000000004005A, flags 0 stub!
# 0178:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0178:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0178:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0178:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0178:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0178:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0178:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0178:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 01b0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01a0:fixme:wintab32:x11drv_tablet_info Return proper size
# 01a0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01a0:fixme:imm:ImeSetActiveContext (0000000000050072, 1): stub
# 01a0:fixme:imm:ImmReleaseContext (000000000013006E, 0000000000050072): stub
# 01a0:fixme:win:RegisterTouchWindow hwnd 000000000013006E, flags 0 stub!
# 01a0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 01a0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01a0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01a0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01a0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01a0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01a0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01a0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 01d8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01c8:fixme:wintab32:x11drv_tablet_info Return proper size
# 01c8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01c8:fixme:imm:ImeSetActiveContext (000000000014006C, 1): stub
# 01c8:fixme:imm:ImmReleaseContext (0000000000060068, 000000000014006C): stub
# 01c8:fixme:win:RegisterTouchWindow hwnd 0000000000060068, flags 0 stub!
# 01c8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 01c8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01c8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01c8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01c8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01c8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01c8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01c8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0200:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 01f0:fixme:wintab32:x11drv_tablet_info Return proper size
# 01f0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 01f0:fixme:imm:ImeSetActiveContext (000000000026006E, 1): stub
# 01f0:fixme:imm:ImmReleaseContext (0000000000160062, 000000000026006E): stub
# 01f0:fixme:win:RegisterTouchWindow hwnd 0000000000160062, flags 0 stub!
# 01f0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 01f0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01f0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 01f0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 01f0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 01f0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 01f0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 01f0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0228:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0218:fixme:wintab32:x11drv_tablet_info Return proper size
# 0218:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0218:fixme:imm:ImeSetActiveContext (0000000000190076, 1): stub
# 0218:fixme:imm:ImmReleaseContext (0000000000160056, 0000000000190076): stub
# 0218:fixme:win:RegisterTouchWindow hwnd 0000000000160056, flags 0 stub!
# 0218:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0218:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0218:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0218:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0218:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0218:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0218:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0218:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0250:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0240:fixme:wintab32:x11drv_tablet_info Return proper size
# 0240:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0240:fixme:imm:ImeSetActiveContext (00000000001A0076, 1): stub
# 0240:fixme:imm:ImmReleaseContext (0000000000090060, 00000000001A0076): stub
# 0240:fixme:win:RegisterTouchWindow hwnd 0000000000090060, flags 0 stub!
# 0240:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0240:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0240:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0240:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0240:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0240:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0240:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0240:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0278:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0268:fixme:wintab32:x11drv_tablet_info Return proper size
# 0268:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0268:fixme:imm:ImeSetActiveContext (00000000001B0076, 1): stub
# 0268:fixme:imm:ImmReleaseContext (0000000000170066, 00000000001B0076): stub
# 0268:fixme:win:RegisterTouchWindow hwnd 0000000000170066, flags 0 stub!
# 0268:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0268:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0268:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0268:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0268:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0268:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0268:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0268:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02a0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0290:fixme:wintab32:x11drv_tablet_info Return proper size
# 0290:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0290:fixme:imm:ImeSetActiveContext (00000000000C0072, 1): stub
# 0290:fixme:imm:ImmReleaseContext (00000000002C0044, 00000000000C0072): stub
# 0290:fixme:win:RegisterTouchWindow hwnd 00000000002C0044, flags 0 stub!
# 0290:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0290:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0290:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0290:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0290:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0290:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0290:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0290:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02c8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 02b8:fixme:wintab32:x11drv_tablet_info Return proper size
# 02b8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 02b8:fixme:imm:ImeSetActiveContext (00000000000C0088, 1): stub
# 02b8:fixme:imm:ImmReleaseContext (00000000000E006A, 00000000000C0088): stub
# 02b8:fixme:win:RegisterTouchWindow hwnd 00000000000E006A, flags 0 stub!
# 02b8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 02b8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02b8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02b8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 02b8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 02b8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 02b8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 02b8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 02f0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 02e0:fixme:wintab32:x11drv_tablet_info Return proper size
# 02e0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 02e0:fixme:imm:ImeSetActiveContext (00000000000E007E, 1): stub
# 02e0:fixme:imm:ImmReleaseContext (00000000000D004C, 00000000000E007E): stub
# 02e0:fixme:win:RegisterTouchWindow hwnd 00000000000D004C, flags 0 stub!
# 02e0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 02e0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02e0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 02e0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 02e0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 02e0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 02e0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 02e0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0318:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0308:fixme:wintab32:x11drv_tablet_info Return proper size
# 0308:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0308:fixme:imm:ImeSetActiveContext (00000000000F007E, 1): stub
# 0308:fixme:imm:ImmReleaseContext (00000000001E007C, 00000000000F007E): stub
# 0308:fixme:win:RegisterTouchWindow hwnd 00000000001E007C, flags 0 stub!
# 0308:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0308:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0308:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0308:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0308:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0308:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0308:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0308:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0340:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0330:fixme:wintab32:x11drv_tablet_info Return proper size
# 0330:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0330:fixme:imm:ImeSetActiveContext (0000000000100072, 1): stub
# 0330:fixme:imm:ImmReleaseContext (0000000000200068, 0000000000100072): stub
# 0330:fixme:win:RegisterTouchWindow hwnd 0000000000200068, flags 0 stub!
# 0330:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0330:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0330:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0330:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0330:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0330:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0330:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0330:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0368:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0358:fixme:wintab32:x11drv_tablet_info Return proper size
# 0358:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0358:fixme:imm:ImeSetActiveContext (00000000002E007C, 1): stub
# 0358:fixme:imm:ImmReleaseContext (0000000000310062, 00000000002E007C): stub
# 0358:fixme:win:RegisterTouchWindow hwnd 0000000000310062, flags 0 stub!
# 0358:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0358:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0358:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0358:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0358:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0358:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0358:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0358:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0390:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0380:fixme:wintab32:x11drv_tablet_info Return proper size
# 0380:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0380:fixme:imm:ImeSetActiveContext (000000000021006C, 1): stub
# 0380:fixme:imm:ImmReleaseContext (000000000021005C, 000000000021006C): stub
# 0380:fixme:win:RegisterTouchWindow hwnd 000000000021005C, flags 0 stub!
# 0380:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0380:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0380:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0380:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0380:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0380:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0380:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0380:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 03b8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03a8:fixme:wintab32:x11drv_tablet_info Return proper size
# 03a8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03a8:fixme:imm:ImeSetActiveContext (0000000000260074, 1): stub
# 03a8:fixme:imm:ImmReleaseContext (000000000014006A, 0000000000260074): stub
# 03a8:fixme:win:RegisterTouchWindow hwnd 000000000014006A, flags 0 stub!
# 03a8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 03a8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03a8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03a8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03a8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03a8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03a8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03a8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 03e0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03d0:fixme:wintab32:x11drv_tablet_info Return proper size
# 03d0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03d0:fixme:imm:ImeSetActiveContext (000000000026007A, 1): stub
# 03d0:fixme:imm:ImmReleaseContext (0000000000140064, 000000000026007A): stub
# 03d0:fixme:win:RegisterTouchWindow hwnd 0000000000140064, flags 0 stub!
# 03d0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 03d0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03d0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03d0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03d0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03d0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03d0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03d0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0408:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 03f8:fixme:wintab32:x11drv_tablet_info Return proper size
# 03f8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 03f8:fixme:imm:ImeSetActiveContext (000000000027007A, 1): stub
# 03f8:fixme:imm:ImmReleaseContext (0000000000450062, 000000000027007A): stub
# 03f8:fixme:win:RegisterTouchWindow hwnd 0000000000450062, flags 0 stub!
# 03f8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 03f8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03f8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 03f8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 03f8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 03f8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 03f8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 03f8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0430:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0420:fixme:wintab32:x11drv_tablet_info Return proper size
# 0420:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0420:fixme:imm:ImeSetActiveContext (000000000028007A, 1): stub
# 0420:fixme:imm:ImmReleaseContext (000000000033005C, 000000000028007A): stub
# 0420:fixme:win:RegisterTouchWindow hwnd 000000000033005C, flags 0 stub!
# 0420:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0420:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0420:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0420:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0420:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0420:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0420:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0420:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0458:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0448:fixme:wintab32:x11drv_tablet_info Return proper size
# 0448:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0448:fixme:imm:ImeSetActiveContext (000000000029007A, 1): stub
# 0448:fixme:imm:ImmReleaseContext (000000000026006A, 000000000029007A): stub
# 0448:fixme:win:RegisterTouchWindow hwnd 000000000026006A, flags 0 stub!
# 0448:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0448:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0448:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0448:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0448:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0448:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0448:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0448:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0480:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0470:fixme:wintab32:x11drv_tablet_info Return proper size
# 0470:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0470:fixme:imm:ImeSetActiveContext (00000000002A007A, 1): stub
# 0470:fixme:imm:ImmReleaseContext (0000000000260064, 00000000002A007A): stub
# 0470:fixme:win:RegisterTouchWindow hwnd 0000000000260064, flags 0 stub!
# 0470:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0470:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0470:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0470:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0470:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0470:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0470:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0470:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04a8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0498:fixme:wintab32:x11drv_tablet_info Return proper size
# 0498:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0498:fixme:imm:ImeSetActiveContext (00000000002B007A, 1): stub
# 0498:fixme:imm:ImmReleaseContext (0000000000570062, 00000000002B007A): stub
# 0498:fixme:win:RegisterTouchWindow hwnd 0000000000570062, flags 0 stub!
# 0498:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0498:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0498:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0498:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0498:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0498:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0498:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0498:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04d0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 04c0:fixme:wintab32:x11drv_tablet_info Return proper size
# 04c0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 04c0:fixme:imm:ImeSetActiveContext (00000000002C007A, 1): stub
# 04c0:fixme:imm:ImmReleaseContext (000000000047005C, 00000000002C007A): stub
# 04c0:fixme:win:RegisterTouchWindow hwnd 000000000047005C, flags 0 stub!
# 04c0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 04c0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04c0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04c0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 04c0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 04c0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 04c0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 04c0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 04f8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 04e8:fixme:wintab32:x11drv_tablet_info Return proper size
# 04e8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 04e8:fixme:imm:ImeSetActiveContext (00000000002D007A, 1): stub
# 04e8:fixme:imm:ImmReleaseContext (00000000003B0068, 00000000002D007A): stub
# 04e8:fixme:win:RegisterTouchWindow hwnd 00000000003B0068, flags 0 stub!
# 04e8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 04e8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04e8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 04e8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 04e8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 04e8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 04e8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 04e8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0520:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0510:fixme:wintab32:x11drv_tablet_info Return proper size
# 0510:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0510:fixme:imm:ImeSetActiveContext (00000000002E007A, 1): stub
# 0510:fixme:imm:ImmReleaseContext (0000000000380064, 00000000002E007A): stub
# 0510:fixme:win:RegisterTouchWindow hwnd 0000000000380064, flags 0 stub!
# 0510:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0510:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0510:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0510:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0510:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0510:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0510:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0510:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0548:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0538:fixme:wintab32:x11drv_tablet_info Return proper size
# 0538:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0538:fixme:imm:ImeSetActiveContext (00000000002F007A, 1): stub
# 0538:fixme:imm:ImmReleaseContext (000000000063004A, 00000000002F007A): stub
# 0538:fixme:win:RegisterTouchWindow hwnd 000000000063004A, flags 0 stub!
# 0538:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0538:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0538:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0538:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0538:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0538:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0538:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0538:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0570:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0560:fixme:wintab32:x11drv_tablet_info Return proper size
# 0560:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0560:fixme:imm:ImeSetActiveContext (000000000030007A, 1): stub
# 0560:fixme:imm:ImmReleaseContext (00000000002E006C, 000000000030007A): stub
# 0560:fixme:win:RegisterTouchWindow hwnd 00000000002E006C, flags 0 stub!
# 0560:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0560:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0560:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0560:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0560:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0560:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0560:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0560:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0598:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0588:fixme:wintab32:x11drv_tablet_info Return proper size
# 0588:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0588:fixme:imm:ImeSetActiveContext (00000000003F007C, 1): stub
# 0588:fixme:imm:ImmReleaseContext (00000000002E004C, 00000000003F007C): stub
# 0588:fixme:win:RegisterTouchWindow hwnd 00000000002E004C, flags 0 stub!
# 0588:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0588:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0588:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0588:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0588:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0588:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0588:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0588:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 05c0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 05b0:fixme:wintab32:x11drv_tablet_info Return proper size
# 05b0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 05b0:fixme:imm:ImeSetActiveContext (000000000040007C, 1): stub
# 05b0:fixme:imm:ImmReleaseContext (00000000003A0076, 000000000040007C): stub
# 05b0:fixme:win:RegisterTouchWindow hwnd 00000000003A0076, flags 0 stub!
# 05b0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 05b0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05b0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05b0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 05b0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 05b0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 05b0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 05b0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 05e8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 05d8:fixme:wintab32:x11drv_tablet_info Return proper size
# 05d8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 05d8:fixme:imm:ImeSetActiveContext (0000000000360074, 1): stub
# 05d8:fixme:imm:ImmReleaseContext (000000000041006A, 0000000000360074): stub
# 05d8:fixme:win:RegisterTouchWindow hwnd 000000000041006A, flags 0 stub!
# 05d8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 05d8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05d8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 05d8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 05d8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 05d8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 05d8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 05d8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0610:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0600:fixme:wintab32:x11drv_tablet_info Return proper size
# 0600:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0600:fixme:imm:ImeSetActiveContext (00000000004C0076, 1): stub
# 0600:fixme:imm:ImmReleaseContext (0000000000490060, 00000000004C0076): stub
# 0600:fixme:win:RegisterTouchWindow hwnd 0000000000490060, flags 0 stub!
# 0600:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0600:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0600:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0600:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0600:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0600:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0600:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0600:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0638:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0628:fixme:wintab32:x11drv_tablet_info Return proper size
# 0628:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0628:fixme:imm:ImeSetActiveContext (000000000043006E, 1): stub
# 0628:fixme:imm:ImmReleaseContext (000000000033005E, 000000000043006E): stub
# 0628:fixme:win:RegisterTouchWindow hwnd 000000000033005E, flags 0 stub!
# 0628:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0628:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0628:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0628:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0628:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0628:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0628:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0628:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0660:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0650:fixme:wintab32:x11drv_tablet_info Return proper size
# 0650:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0650:fixme:imm:ImeSetActiveContext (000000000037007A, 1): stub
# 0650:fixme:imm:ImmReleaseContext (0000000000540068, 000000000037007A): stub
# 0650:fixme:win:RegisterTouchWindow hwnd 0000000000540068, flags 0 stub!
# 0650:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0650:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0650:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0650:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0650:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0650:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0650:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0650:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0688:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0678:fixme:wintab32:x11drv_tablet_info Return proper size
# 0678:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0678:fixme:imm:ImeSetActiveContext (000000000038007A, 1): stub
# 0678:fixme:imm:ImmReleaseContext (0000000000420064, 000000000038007A): stub
# 0678:fixme:win:RegisterTouchWindow hwnd 0000000000420064, flags 0 stub!
# 0678:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0678:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0678:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0678:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0678:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0678:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0678:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0678:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 06b0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06a0:fixme:wintab32:x11drv_tablet_info Return proper size
# 06a0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06a0:fixme:imm:ImeSetActiveContext (000000000039007A, 1): stub
# 06a0:fixme:imm:ImmReleaseContext (00000000005D0060, 000000000039007A): stub
# 06a0:fixme:win:RegisterTouchWindow hwnd 00000000005D0060, flags 0 stub!
# 06a0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 06a0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06a0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06a0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06a0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06a0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06a0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06a0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 06d8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06c8:fixme:wintab32:x11drv_tablet_info Return proper size
# 06c8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06c8:fixme:imm:ImeSetActiveContext (00000000003A007A, 1): stub
# 06c8:fixme:imm:ImmReleaseContext (000000000049005E, 00000000003A007A): stub
# 06c8:fixme:win:RegisterTouchWindow hwnd 000000000049005E, flags 0 stub!
# 06c8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 06c8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06c8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06c8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06c8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06c8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06c8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06c8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0700:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 06f0:fixme:wintab32:x11drv_tablet_info Return proper size
# 06f0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 06f0:fixme:imm:ImeSetActiveContext (0000000000530076, 1): stub
# 06f0:fixme:imm:ImmReleaseContext (0000000000680068, 0000000000530076): stub
# 06f0:fixme:win:RegisterTouchWindow hwnd 0000000000680068, flags 0 stub!
# 06f0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 06f0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06f0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 06f0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 06f0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 06f0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 06f0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 06f0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0728:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0718:fixme:wintab32:x11drv_tablet_info Return proper size
# 0718:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0718:fixme:imm:ImeSetActiveContext (0000000000540076, 1): stub
# 0718:fixme:imm:ImmReleaseContext (0000000000530064, 0000000000540076): stub
# 0718:fixme:win:RegisterTouchWindow hwnd 0000000000530064, flags 0 stub!
# 0718:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0718:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0718:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0718:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0718:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0718:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0718:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0718:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0750:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0740:fixme:wintab32:x11drv_tablet_info Return proper size
# 0740:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0740:fixme:imm:ImeSetActiveContext (0000000000550076, 1): stub
# 0740:fixme:imm:ImmReleaseContext (00000000006F0060, 0000000000550076): stub
# 0740:fixme:win:RegisterTouchWindow hwnd 00000000006F0060, flags 0 stub!
# 0740:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0740:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0740:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0740:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0740:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0740:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0740:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0740:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0778:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0768:fixme:wintab32:x11drv_tablet_info Return proper size
# 0768:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0768:fixme:imm:ImeSetActiveContext (00000000004D007C, 1): stub
# 0768:fixme:imm:ImmReleaseContext (0000000000900048, 00000000004D007C): stub
# 0768:fixme:win:RegisterTouchWindow hwnd 0000000000900048, flags 0 stub!
# 0768:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0768:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0768:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0768:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0768:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0768:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0768:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0768:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07a0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0790:fixme:wintab32:x11drv_tablet_info Return proper size
# 0790:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0790:fixme:imm:ImeSetActiveContext (00000000004E007C, 1): stub
# 0790:fixme:imm:ImmReleaseContext (000000000049004C, 00000000004E007C): stub
# 0790:fixme:win:RegisterTouchWindow hwnd 000000000049004C, flags 0 stub!
# 0790:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0790:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0790:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0790:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0790:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0790:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0790:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0790:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07c8:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 07b8:fixme:wintab32:x11drv_tablet_info Return proper size
# 07b8:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 07b8:fixme:imm:ImeSetActiveContext (00000000005C007E, 1): stub
# 07b8:fixme:imm:ImmReleaseContext (0000000000580076, 00000000005C007E): stub
# 07b8:fixme:win:RegisterTouchWindow hwnd 0000000000580076, flags 0 stub!
# 07b8:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 07b8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07b8:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07b8:fixme:win:NtUserFlashWindowEx 0x11b380 - semi-stub
# 07b8:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 07b8:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 07b8:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 07b8:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 07b8:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 07f0:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 07e0:fixme:wintab32:x11drv_tablet_info Return proper size
# 07e0:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 07e0:fixme:imm:ImeSetActiveContext (0000000000450074, 1): stub
# 07e0:fixme:imm:ImmReleaseContext (0000000000B00046, 0000000000450074): stub
# 07e0:fixme:win:RegisterTouchWindow hwnd 0000000000B00046, flags 0 stub!
# 07e0:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 07e0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07e0:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 07e0:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 07e0:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 07e0:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 07e0:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 07e0:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0818:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0808:fixme:wintab32:x11drv_tablet_info Return proper size
# 0808:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0808:fixme:imm:ImeSetActiveContext (00000000005A0076, 1): stub
# 0808:fixme:imm:ImmReleaseContext (00000000005E007E, 00000000005A0076): stub
# 0808:fixme:win:RegisterTouchWindow hwnd 00000000005E007E, flags 0 stub!
# 0808:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0808:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0808:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0808:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0808:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0808:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0808:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0808:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0104:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0030:fixme:wintab32:x11drv_tablet_info Return proper size
# 0030:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0030:fixme:imm:ImeSetActiveContext (00000000002F0082, 1): stub
# 0030:fixme:imm:ImmReleaseContext (0000000000B10044, 00000000002F0082): stub
# 0030:fixme:win:RegisterTouchWindow hwnd 0000000000B10044, flags 0 stub!
# 0030:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0030:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0030:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0030:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0030:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0030:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0030:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0030:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0138:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0100:fixme:wintab32:x11drv_tablet_info Return proper size
# 0100:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0100:fixme:imm:ImeSetActiveContext (0000000000300082, 1): stub
# 0100:fixme:imm:ImmReleaseContext (0000000000850064, 0000000000300082): stub
# 0100:fixme:win:RegisterTouchWindow hwnd 0000000000850064, flags 0 stub!
# 0100:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0100:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0100:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0100:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0160:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0128:fixme:wintab32:x11drv_tablet_info Return proper size
# 0128:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0128:fixme:imm:ImeSetActiveContext (00000000005D0076, 1): stub
# 0128:fixme:imm:ImmReleaseContext (000000000064006A, 00000000005D0076): stub
# 0128:fixme:win:RegisterTouchWindow hwnd 000000000064006A, flags 0 stub!
# 0128:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0128:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0128:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0128:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image
# 0188:fixme:tasklist:wmain stub: L"tasklist" L"/nh" L"/fo" L"csv" L"/fi" L"Imagename eq soap64.exe" L"/fi" L"Status eq Running"
# 0150:fixme:wintab32:x11drv_tablet_info Return proper size
# 0150:fixme:win:NtUserFlashWindowEx 0x11f190 - semi-stub
# 0150:fixme:imm:ImeSetActiveContext (00000000005E0076, 1): stub
# 0150:fixme:imm:ImmReleaseContext (00000000004D0070, 00000000005E0076): stub
# 0150:fixme:win:RegisterTouchWindow hwnd 00000000004D0070, flags 0 stub!
# 0150:fixme:wgl:X11DRV_wglGetPixelFormatAttribivARB unsupported 2008 WGL Attribute
# 0150:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0150:fixme:msg:pack_message msg 80 (WM_SETICON) not supported yet
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000640F8470) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000630D2810) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (000000006590D5E0) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (0000000061063BA0) stub
# 0150:fixme:msvcrt:__clean_type_info_names_internal (00000000672BF920) stub
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: Interlace handling should be turned on when using png_read_image

# %% [markdown]
# ## Generate Barcodes

# %%
from zz_persistence import *

diagrams = {}
diagrams_clique = {}

filepaths = get_csv_files(folder)
for filepath in filepaths:
    if not filepath.endswith("Contact Analysis.csv"):
        continue
    contact_plan = ca.contact_analysis_parser(filepath)
    graph = ca.construct_graph(contact_plan)
    
    weighted_simplex = ca.construct_weighted_simplex(graph)
    clique_complex = ca.construct_clique_complex(graph)
    
    zz, dgms, cells = calculate_zz_persistence(weighted_simplex)
    zz_clique, dgms_clique, cells_clique = calculate_zz_persistence(clique_complex)
    
    diagrams[filepath.split("/")[-1]] = dgms
    diagrams_clique[filepath.split("/")[-1]] = dgms_clique
    
# print(diagrams)
# print(diagrams_clique)

# %%
dim = 1

# %% [markdown]
# ## Compare Earth / Moon Simulations

# %%
# Compare Earth / Moon
for i in range(n):
    for j in range(i + 1, n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_moon_" + str(j) + " Contact Analysis.csv"]
        
        diagram_a_clique = diagrams_clique["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_moon_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))

# %% [markdown]
# ## Compare Earth / Mars Simulations

# %%
# Compare Earth / Mars
for i in range(n):
    for j in range(i + 1, n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_mars_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_mars_" + str(j) + " Contact Analysis.csv"]

        diagram_a_clique = diagrams_clique["emm_mars_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_mars_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))

# %% [markdown]
# ## Cross Compare Moon / Mars

# %%
# Cross Compare Moon / Mars
for i in range(n):
    for j in range(n):
        print("{} : {}".format(i, j))

        diagram_a = diagrams["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b = diagrams["emm_mars_" + str(j) + " Contact Analysis.csv"]
        
        diagram_a_clique = diagrams_clique["emm_moon_" + str(i) + " Contact Analysis.csv"]
        diagram_b_clique = diagrams_clique["emm_mars_" + str(j) + " Contact Analysis.csv"]

        wdist = d.wasserstein_distance(diagram_a[dim], diagram_b[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams: {}".format(dim, wdist))

        bdist = d.bottleneck_distance(diagram_a[dim], diagram_b[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams: {}".format(dim, bdist))
        
        wdist_clique = d.wasserstein_distance(diagram_a_clique[dim], diagram_b_clique[dim], q=2)
        print("2-Wasserstein distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, wdist_clique))

        bdist_clique = d.bottleneck_distance(diagram_a_clique[dim], diagram_b_clique[dim])
        print("Bottleneck distance between {}-dimensional persistence diagrams (Clique): {}".format(dim, bdist_clique))
